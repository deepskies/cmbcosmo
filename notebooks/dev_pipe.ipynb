# %% [markdown]
# this notebook test runs the code in development in the pipeline.

# %%
# %%bash
#
# configpath='../runscripts/configs/config_dev.yml'
#
# python ~/deepskies/cmbcosmo/cmbcosmo/run_inference.py \
#           					--config-path=${configpath}
# Out:
# 2023-10-12 14:28:52.481685
#
# ## inputs: {'config_path': '../runscripts/configs/config_dev.yml', 'mcmc': False, 'sbi': False}
#
# # setup_config: added 1:
# ['paths.outdir']
#
# initial config: {'FORCAMB': {'DoLensing': True}, 'ITERABLES': {'InitPower.r': array([0.01 , 0.055, 0.1  ]), 'Alens': array([0.8, 1. , 1.2])}, 'seed': 0, 'verbose': 1, 'normalize_cls': False, 'TT_units': 'muK', 'outfile_dir': 'outfiles', 'noise_type': 'white', 'noise_uKarcmin': 5, 'beamfwhm_arcmin': 3, 'extra_l': 300, 'max_l_use': 10000}
#
# updated verbose in UserParams to 0
# updated seed in UserParams to 924
# updated InitPower.r in CAMBparams to 0.04
#
# ## not sure what were doing here since run_mcmc and run_sbi are set to False ..

# %%
# %%bash
#
# configpath='../runscripts/configs/config_dev.yml'
#
# python ~/deepskies/cmbcosmo/cmbcosmo/run_inference.py \
#           					--config-path=${configpath} --mcmc --sbi
# Out:
# /Users/humnaawan/deepskies/cmbcosmo/cmbcosmo/setup_mcmc.py:35: RuntimeWarning: invalid value encountered in divide
#   chi2 = np.nansum((theory_vec - self.datavector)**2 / theory_vec)
# 2023-10-12 14:29:00.716754
#
# ## inputs: {'config_path': '../runscripts/configs/config_dev.yml', 'mcmc': True, 'sbi': True}
#
# # setup_config: added 1:
# ['paths.outdir']
#
# initial config: {'FORCAMB': {'DoLensing': True}, 'ITERABLES': {'InitPower.r': array([0.01 , 0.055, 0.1  ]), 'Alens': array([0.8, 1. , 1.2])}, 'seed': 0, 'verbose': 1, 'normalize_cls': False, 'TT_units': 'muK', 'outfile_dir': 'outfiles', 'noise_type': 'white', 'noise_uKarcmin': 5, 'beamfwhm_arcmin': 3, 'extra_l': 300, 'max_l_use': 10000}
#
# updated verbose in UserParams to 0
# updated seed in UserParams to 924
# updated InitPower.r in CAMBparams to 0.04
#
# ## running mcmc ..
#
# ## burning in ...
# updated InitPower.r in CAMBparams to [0.1397368]
# updated InitPower.r in CAMBparams to [0.18008263]
# ...
